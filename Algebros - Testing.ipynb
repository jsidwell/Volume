# %%
import AlgebrosModularisation

import sympy as sym

# %%
def test_SolveFuncs():
    "this tests 'SolveFuncs' for example functions"
    x3coeff = 1
    x2coeff = 0
    x1coeff = 0
    x0coeff = 0
    m = 1
    n = 0
    solutions = AlgebrosModularisation.solveset(equation)
    expected_solutions = [-1, 0, 1]
    assert solutions == expected_solutions, f"Incorrect solutions obtained, the code obtained{solutions}"

# %%
def test_GetVolume():
    "this tests 'GetVolume' for example functions"
    x3coeff = 1
    x2coeff = 0
    x1coeff = 0
    x0coeff = 0
    m = 1
    n = 0
    Volume = pi*(expression**2)
    expected_volume = pi*(x**2)-pi*2*(x**4)+pi*(x**6)
    assert Volume == expected_volume, f"Incorrect integral obtained, the code obtained{Volume}"

# %%
def test_GetArea():
    "this tests 'GetArea' for example functions"
    x3coeff = 1
    x2coeff = 0
    x1coeff = 0
    x0coeff = 0
    m = 1
    n = 0
    totalArea = abs(sym.integrate(vol[0], (x , sol[3].args[0], sol[3].args[1])))
    totalArea = totalArea + abs(sym.integrate(vol[0], (x , sol[3].args[1], sol[3].args[2])))
    expected_totalarea = (16*pi)/105
    assert totalArea == expected_totalarea, f"Incorrect volume obtained, the code obtained{totalArea}"

# %%
def test_AquariumModel():
    "this tests 'AquariumModel' for example functions"
    x3coeff = 1
    x2coeff = 0
    x1coeff = 0
    x0coeff = 0
    m = 1
    n = 0
    Tube = 0.2
    TimeHours = 0.06
    Rate = round(Aquarium/TimeMinutes,3)
    expected_rate = 0.077
    assert Rate == expected_rate, f"incorect rate obtained, the code obtained{Rate}"
